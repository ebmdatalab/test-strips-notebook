# %% [markdown]
# ## Blood Gluse Test Strips Price Information

# %% [markdown]
# A user has gotten in touch as they require price information on blood glucose test strips for analysis they want to carry out. Our [OpenPrescribing drug tariff browser/viewer](https://openprescribing.net/tariff/) currently only support part 8 whereas test strips are located in the device section. [Prescribing patterns of blood glucose test strips](https://openprescribing.net/chemical/0601060D0/) can be viewed on OpenPrescribing.
#
# However on our price per unit tool we do incoproarte blood glucose test strips so we do have the price paid (accepted slightly different to drug tariff) in our database. The [PPU for blood glucose test strips and possible savings can be seen here](https://openprescribing.net/national/england/0601060D0AAA0A0/price-per-unit/?date=2020-05-01).
#
# In this notebook we will extract the median price paid for the user and export to csv for their own (and others) analysis.

# %%
#import libraries
import pandas as pd
import numpy as np
import os
from ebmdatalab import bq, maps, charts #possibly do graphs at later stage.

# %%
#this sets £ and pence properly - removed presently to display the individual strip price as they are priced as boxes in tariff.
#pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# # SQL

# %%
sql = '''
SELECT
ppu.date,
ppu.bnf_code,
dmd.nm,
ppu.median_price_per_unit
FROM
ebmdatalab.measures.vw__median_price_per_unit as ppu
LEFT JOIN
ebmdatalab.dmd.amp as dmd
ON
ppu.bnf_code = dmd.bnf_code
WHERE 
ppu.bnf_code LIKE '0601060D0%'
ORDER BY
ppu.bnf_code,
ppu.date
'''




df_median_ppu_bgt = bq.cached_read(sql, csv_path=os.path.join('..','data','df_median_ppu_bgt.csv'))
df_median_ppu_bgt.head(50)
# Out:
#                          date         bnf_code  \
# 0   2010-08-01 00:00:00+00:00  0601060D0BEABA0
# 1   2010-09-01 00:00:00+00:00  0601060D0BEABA0
# 2   2010-10-01 00:00:00+00:00  0601060D0BEABA0
# 3   2010-11-01 00:00:00+00:00  0601060D0BEABA0
# 4   2010-12-01 00:00:00+00:00  0601060D0BEABA0
# 5   2010-08-01 00:00:00+00:00  0601060D0BHAAA0
# 6   2010-09-01 00:00:00+00:00  0601060D0BHAAA0
# 7   2010-10-01 00:00:00+00:00  0601060D0BHAAA0
# 8   2010-11-01 00:00:00+00:00  0601060D0BHAAA0
# 9   2010-12-01 00:00:00+00:00  0601060D0BHAAA0
# 10  2011-01-01 00:00:00+00:00  0601060D0BHAAA0
# 11  2011-02-01 00:00:00+00:00  0601060D0BHAAA0
# 12  2011-03-01 00:00:00+00:00  0601060D0BHAAA0
# 13  2011-04-01 00:00:00+00:00  0601060D0BHAAA0
# 14  2011-05-01 00:00:00+00:00  0601060D0BHAAA0
# 15  2011-06-01 00:00:00+00:00  0601060D0BHAAA0
# 16  2011-07-01 00:00:00+00:00  0601060D0BHAAA0
# 17  2011-08-01 00:00:00+00:00  0601060D0BHAAA0
# 18  2011-09-01 00:00:00+00:00  0601060D0BHAAA0
# 19  2011-10-01 00:00:00+00:00  0601060D0BHAAA0
# 20  2011-11-01 00:00:00+00:00  0601060D0BHAAA0
# 21  2011-12-01 00:00:00+00:00  0601060D0BHAAA0
# 22  2010-08-01 00:00:00+00:00  0601060D0BHABA0
# 23  2010-09-01 00:00:00+00:00  0601060D0BHABA0
# 24  2010-10-01 00:00:00+00:00  0601060D0BHABA0
# 25  2010-11-01 00:00:00+00:00  0601060D0BHABA0
# 26  2010-12-01 00:00:00+00:00  0601060D0BHABA0
# 27  2011-01-01 00:00:00+00:00  0601060D0BHABA0
# 28  2011-02-01 00:00:00+00:00  0601060D0BHABA0
# 29  2011-03-01 00:00:00+00:00  0601060D0BHABA0
# 30  2011-04-01 00:00:00+00:00  0601060D0BHABA0
# 31  2011-05-01 00:00:00+00:00  0601060D0BHABA0
# 32  2011-06-01 00:00:00+00:00  0601060D0BHABA0
# 33  2011-07-01 00:00:00+00:00  0601060D0BHABA0
# 34  2011-08-01 00:00:00+00:00  0601060D0BHABA0
# 35  2011-09-01 00:00:00+00:00  0601060D0BHABA0
# 36  2011-10-01 00:00:00+00:00  0601060D0BHABA0
# 37  2011-11-01 00:00:00+00:00  0601060D0BHABA0
# 38  2011-12-01 00:00:00+00:00  0601060D0BHABA0
# 39  2012-01-01 00:00:00+00:00  0601060D0BHABA0
# 40  2012-02-01 00:00:00+00:00  0601060D0BHABA0
# 41  2012-03-01 00:00:00+00:00  0601060D0BHABA0
# 42  2012-04-01 00:00:00+00:00  0601060D0BHABA0
# 43  2012-05-01 00:00:00+00:00  0601060D0BHABA0
# 44  2012-06-01 00:00:00+00:00  0601060D0BHABA0
# 45  2012-07-01 00:00:00+00:00  0601060D0BHABA0
# 46  2012-08-01 00:00:00+00:00  0601060D0BHABA0
# 47  2012-09-01 00:00:00+00:00  0601060D0BHABA0
# 48  2012-10-01 00:00:00+00:00  0601060D0BHABA0
# 49  2012-11-01 00:00:00+00:00  0601060D0BHABA0
#
#                                   nm  median_price_per_unit
# 0   Hypoguard Supreme testing strips                 0.2400
# 1   Hypoguard Supreme testing strips                 0.2400
# 2   Hypoguard Supreme testing strips                 0.2400
# 3   Hypoguard Supreme testing strips                 0.2400
# 4   Hypoguard Supreme testing strips                 0.2400
# 5            OneTouch testing strips                 0.2918
# 6            OneTouch testing strips                 0.2918
# 7            OneTouch testing strips                 0.2918
# 8            OneTouch testing strips                 0.2918
# 9            OneTouch testing strips                 0.2918
# 10           OneTouch testing strips                 0.2918
# 11           OneTouch testing strips                 0.2918
# 12           OneTouch testing strips                 0.2918
# 13           OneTouch testing strips                 0.2918
# 14           OneTouch testing strips                 0.2918
# 15           OneTouch testing strips                 0.2918
# 16           OneTouch testing strips                 0.2918
# 17           OneTouch testing strips                 0.2968
# 18           OneTouch testing strips                 0.2968
# 19           OneTouch testing strips                 0.2968
# 20           OneTouch testing strips                 0.2968
# 21           OneTouch testing strips                 0.2968
# 22     OneTouch Ultra testing strips                 0.2950
# 23     OneTouch Ultra testing strips                 0.2950
# 24     OneTouch Ultra testing strips                 0.2950
# 25     OneTouch Ultra testing strips                 0.2950
# 26     OneTouch Ultra testing strips                 0.2950
# 27     OneTouch Ultra testing strips                 0.2950
# 28     OneTouch Ultra testing strips                 0.2950
# 29     OneTouch Ultra testing strips                 0.2950
# 30     OneTouch Ultra testing strips                 0.2950
# 31     OneTouch Ultra testing strips                 0.2950
# 32     OneTouch Ultra testing strips                 0.2950
# 33     OneTouch Ultra testing strips                 0.2950
# 34     OneTouch Ultra testing strips                 0.3000
# 35     OneTouch Ultra testing strips                 0.3000
# 36     OneTouch Ultra testing strips                 0.3000
# 37     OneTouch Ultra testing strips                 0.3000
# 38     OneTouch Ultra testing strips                 0.3000
# 39     OneTouch Ultra testing strips                 0.3000
# 40     OneTouch Ultra testing strips                 0.3000
# 41     OneTouch Ultra testing strips                 0.3000
# 42     OneTouch Ultra testing strips                 0.3000
# 43     OneTouch Ultra testing strips                 0.3000
# 44     OneTouch Ultra testing strips                 0.3000
# 45     OneTouch Ultra testing strips                 0.3000
# 46     OneTouch Ultra testing strips                 0.3054
# 47     OneTouch Ultra testing strips                 0.3054
# 48     OneTouch Ultra testing strips                 0.3054
# 49     OneTouch Ultra testing strips                 0.3054
